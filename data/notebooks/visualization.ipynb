# %% [markdown]
# # Airport Map Visualization
#
# This project demonstrates how to download airport data from the X-Plane Scenery Gateway and create interactive airport maps.
#
# ## Why X-Plane Scenery Gateway?
#
# The X-Plane scenery system provides a rich source of airport data (runways, taxiways, frequencies, lighting systems, etc.) in a simple `.dat` text format. These datasets are:
#
# - **Free and easily accessible** via the official API
# - **Useful for academic or personal projects**, such as visualizations, simulations, or research
# - **Comprehensive data** including precise coordinates, elevations, surface types, and lighting information
#
# ## Limitations
#
# ⚠️ **Not suitable for real-world operational projects**: Updates depend on community contributors who modify airports in their free time, so the data may not always reflect real-time changes.
#
# ✅ **Best for**: Educational, simulation, or visualization purposes.
#
# ## File Format Overview
#
# The airport data is stored in `apt.dat` files with **row codes** describing different elements:
#
# | Row Code | Element Type | Description |
# |----------|--------------|-------------|
# | **1** | Airport Header | Basic airport information |
# | **100** | Runway | Runway definitions with both ends |
# | **110** | Pavement | Taxiways, ramps, aprons |
# | **120** | Linear Feature | Roads, boundaries |
# | **130** | Airport Boundary | Perimeter definition |
# | **1200** | Taxi Route Network | Ground movement routes |
# | **1300** | Startup Locations | Aircraft parking positions |
#
# ## Runway Format Example
#
# Here's a complete runway definition from `apt.dat`:
#
# ```
# 100  29.87 1 0 0.15 0 2 1 13L 47.53801700 -122.30746100 73.15 0.00 31R 47.52068300 -122.30746100 73.15 0.00
# ```
#
# ### Field Breakdown:
#
# | Field | Value | Description |
# |-------|-------|-------------|
# | **1** | `100` | **Row code**: indicates this line describes a runway |
# | **2** | `29.87` | **Runway width** in meters |
# | **3** | `1` | **Surface type** (1 = asphalt, 2 = concrete, 3 = grass, etc.) |
# | **4** | `0` | **Water runway** indicator (0 = no, 1 = yes) |
# | **5** | `0.15` | **Runway friction coefficient** |
# | **6** | `0` | **Shoulder** (reinforced edge): 0 = none |
# | **7** | `2` | **Lighting type** (0 = none, 1 = basic, 2 = standard, etc.) |
# | **8** | `1` | **Runway markings** (0 = none, 1 = basic, 2 = non-precision, etc.) |
#
# ### Runway End 1 (13L):
# | Field | Value | Description |
# |-------|-------|-------------|
# | **9** | `13L` | **Runway identifier** for first end |
# | **10** | `47.53801700` | **Latitude** in decimal degrees |
# | **11** | `-122.30746100` | **Longitude** in decimal degrees |
# | **12** | `73.15` | **Elevation** in meters above sea level |
# | **13** | `0.00` | **Threshold displacement** in meters |
#
# ### Runway End 2 (31R):
# | Field | Value | Description |
# |-------|-------|-------------|
# | **14** | `31R` | **Runway identifier** for second end |
# | **15** | `47.52068300` | **Latitude** in decimal degrees |
# | **16** | `-122.30746100` | **Longitude** in decimal degrees |
# | **17** | `73.15` | **Elevation** in meters above sea level |
# | **18** | `0.00` | **Threshold displacement** in meters |
#
# > **Note**: Runway ends are always opposite (approximately 180° difference). In this example, 13L points toward ~130° and 31R toward ~310°.
#
# <div style="display: flex; justify-content: space-between; gap: 1rem;">
#     <div>
#         <h3>Surface Type Codes</h3>
#         <table>
#             <thead>
#                 <tr>
#                     <th>Code</th>
#                     <th>Surface Type</th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <tr><td>1</td><td>Asphalt</td></tr>
#                 <tr><td>2</td><td>Concrete</td></tr>
#                 <tr><td>3</td><td>Turf/grass</td></tr>
#                 <tr><td>4</td><td>Dirt</td></tr>
#                 <tr><td>5</td><td>Gravel</td></tr>
#                 <tr><td>12</td><td>Dry lakebed</td></tr>
#                 <tr><td>13</td><td>Water runways</td></tr>
#                 <tr><td>14</td><td>Snow/ice</td></tr>
#                 <tr><td>15</td><td>Transparent (for helipad overlays)</td></tr>
#             </tbody>
#         </table>
#     </div>
#     <div>
#         <h3>Lighting Type Codes</h3>
#         <table>
#             <thead>
#                 <tr>
#                     <th>Code</th>
#                     <th>Lighting Type</th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <tr><td>0</td><td>No lighting</td></tr>
#                 <tr><td>1</td><td>Pilot Controlled Lighting</td></tr>
#                 <tr><td>2</td><td>Runway lighting</td></tr>
#                 <tr><td>3</td><td>Taxiway lighting</td></tr>
#                 <tr><td>4</td><td>REIL (Runway End Identifier Lights)</td></tr>
#                 <tr><td>5</td><td>CALVERT lighting system</td></tr>
#             </tbody>
#         </table>
#     </div>
#     <div>
#         <h3>Runway Marking Codes</h3>
#         <table>
#             <thead>
#                 <tr>
#                     <th>Code</th>
#                     <th>Marking Type</th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <tr><td>0</td><td>No markings</td></tr>
#                 <tr><td>1</td><td>Visual markings</td></tr>
#                 <tr><td>2</td><td>Non-precision approach markings</td></tr>
#                 <tr><td>3</td><td>Precision approach markings</td></tr>
#             </tbody>
#         </table>
#     </div>
# </div>
#
# ### Airport Header (Row Code 1)
# ```
# 1   2000 1 0 KSEA Seattle-Tacoma Intl
# ```
#
# ## Resources
#
# - [X-Plane Scenery Gateway](https://gateway.x-plane.com/)
# - [Airport Data (apt.dat) 12.00 File Format Specification](https://developer.x-plane.com/article/airport-data-apt-dat-12-00-file-format-specification/)
# - [X-Plane Developer Documentation](https://developer.x-plane.com/)

# %%
#!pip install xplane_airports folium

# %%
from get_data import XPlaneAirportDownloader
from airport_graph import AirportMapVisualizer

# %%
AIRPORT = 'LEBL'.upper()
OUTPUT_DIR = './airport_data'
INPUT_DIR = f'./airport_data/{AIRPORT}/{AIRPORT}.dat'

# %% [markdown]
# ### Get .dat file

# %%
dowloader = XPlaneAirportDownloader(
    AIRPORT, 
    output_directory= './airport_data'
)
dowloader.download()
# Out:
# 📥 Downloading LEBL...
# ✅ LEBL download completed (0.77 MB) - Saved in: /home/santi/Documents/AIrport/data/airport_data/LEBL
# PosixPath('/home/santi/Documents/AIrport/data/airport_data/LEBL/LEBL.dat')

# %%
visualizer = AirportMapVisualizer(INPUT_DIR)
visualizer.save()
# Out:
# Official airport center: (41.296944444, 2.078333333)
# Creating map centered at: (41.296944444, 2.078333333)
# Map saved as: airport_data/LEBL/LEBL_airport_map.html
# Map saved as: airport_data/LEBL/LEBL_airport_map.html

# %% [markdown]
# ### Show map

# %%
visualizer.display()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3e4292f7abc24541a2a01131a44b2d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#         &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;LEBL Barcelona - El Prat (LEBL)&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3e4292f7abc24541a2a01131a44b2d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3e4292f7abc24541a2a01131a44b2d3 = L.map(
#                 &quot;map_a3e4292f7abc24541a2a01131a44b2d3&quot;,
#                 {
#                     center: [41.296944444, 2.078333333],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71cf68f9d117493771c59d962423f443 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_71cf68f9d117493771c59d962423f443.addTo(map_a3e4292f7abc24541a2a01131a44b2d3);
#
#
#             var feature_group_770e9287601920bd77650c37545b8d97 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var poly_line_508de0b16df3c7fe7f7be560721c5dbc = L.polyline(
#                 [[41.28773163, 2.08481973], [41.30928753, 2.0946638]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.9, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(feature_group_770e9287601920bd77650c37545b8d97);
#
#
#         var popup_154e7a0f0dfed4a46c3b5cf8d0b4e978 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d937bb37b242ab974bd50f1c19bf0693 = $(`&lt;div id=&quot;html_d937bb37b242ab974bd50f1c19bf0693&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Runway 02/20&lt;/b&gt;&lt;br&gt;         Width: 45.11m&lt;br&gt;         Surface: 1&lt;br&gt;         Smoothness: 0.0&lt;br&gt;         Center Lighting: 1&lt;br&gt;         Edge Lighting: 2&lt;br&gt;         Distance Signs: 0&lt;br&gt;         &lt;hr&gt;         &lt;b&gt;02 End:&lt;/b&gt;&lt;br&gt;         Lat: 41.287732&lt;br&gt;         Lon: 2.084820&lt;br&gt;         &lt;b&gt;20 End:&lt;/b&gt;&lt;br&gt;         Lat: 41.309288&lt;br&gt;         Lon: 2.094664         &lt;/div&gt;`)[0];
#                 popup_154e7a0f0dfed4a46c3b5cf8d0b4e978.setContent(html_d937bb37b242ab974bd50f1c19bf0693);
#
#
#
#         poly_line_508de0b16df3c7fe7f7be560721c5dbc.bindPopup(popup_154e7a0f0dfed4a46c3b5cf8d0b4e978)
#         ;
#
#
#
#
#             var circle_marker_157182c51d037b4e06d5b69241389f28 = L.circleMarker(
#                 [41.28773163, 2.08481973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;white&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(feature_group_770e9287601920bd77650c37545b8d97);
#
#
#         var popup_ff3b62fe04f4d027e5ec6bc2cdb58da2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2de8f1ac3ae977ab9920455efe47b07d = $(`&lt;div id=&quot;html_2de8f1ac3ae977ab9920455efe47b07d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Runway 02&lt;br&gt;Displacement: 0.0m&lt;br&gt;Overrun: 0.0m&lt;br&gt;Marking: 3&lt;/div&gt;`)[0];
#                 popup_ff3b62fe04f4d027e5ec6bc2cdb58da2.setContent(html_2de8f1ac3ae977ab9920455efe47b07d);
#
#
#
#         circle_marker_157182c51d037b4e06d5b69241389f28.bindPopup(popup_ff3b62fe04f4d027e5ec6bc2cdb58da2)
#         ;
#
#
#
#
#             var circle_marker_68ae9c42ce41ddc2e7aea5f8708ffbc6 = L.circleMarker(
#                 [41.30928753, 2.0946638],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;white&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quo
